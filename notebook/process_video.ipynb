# %% [markdown]
# ### Extract frames from video

# %%
import cv2  # still used to save images out
import os
import numpy as np
from decord import VideoReader
from decord import cpu, gpu


def extract_frames(video_path, frames_dir, overwrite=False, start=-1, end=-1, every=1):
    """
    Extract frames from a video using decord's VideoReader
    :param video_path: path of the video
    :param frames_dir: the directory to save the frames
    :param overwrite: to overwrite frames that already exist?
    :param start: start frame
    :param end: end frame
    :param every: frame spacing
    :return: count of images saved
    """

    video_path = os.path.normpath(video_path)  # make the paths OS (Windows) compatible
    frames_dir = os.path.normpath(frames_dir)  # make the paths OS (Windows) compatible

    video_dir, video_filename = os.path.split(video_path)  # get the video path and filename from the path

    assert os.path.exists(video_path)  # assert the video file exists

    # load the VideoReader
    vr = VideoReader(video_path, ctx=cpu(0))  # can set to cpu or gpu .. ctx=gpu(0)
                     
    if start < 0:  # if start isn't specified lets assume 0
        start = 0
    if end < 0:  # if end isn't specified assume the end of the video
        end = len(vr)

    frames_list = list(range(start, end, every))
    saved_count = 0

    if every > 25 and len(frames_list) < 1000:  # this is faster for every > 25 frames and can fit in memory
        frames = vr.get_batch(frames_list).asnumpy()

        for index, frame in zip(frames_list, frames):  # lets loop through the frames until the end
            save_path = os.path.join(frames_dir, video_filename, "{:010d}.jpg".format(index))  # create the save path
            if not os.path.exists(save_path) or overwrite:  # if it doesn't exist or we want to overwrite anyways
                cv2.imwrite(save_path, cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))  # save the extracted image
                saved_count += 1  # increment our counter by one

    else:  # this is faster for every <25 and consumes small memory
        for index in range(start, end):  # lets loop through the frames until the end
            frame = vr[index]  # read an image from the capture
            
            if index % every == 0:  # if this is a frame we want to write out based on the 'every' argument
                save_path = os.path.join(frames_dir, video_filename, "{:010d}.jpg".format(index))  # create the save path
                if not os.path.exists(save_path) or overwrite:  # if it doesn't exist or we want to overwrite anyways
                    cv2.imwrite(save_path, cv2.cvtColor(frame.asnumpy(), cv2.COLOR_RGB2BGR))  # save the extracted image
                    saved_count += 1  # increment our counter by one

    return saved_count  # and return the count of the images we saved


def video_to_frames(video_path, frames_dir, overwrite=False, every=1):
    """
    Extracts the frames from a video
    :param video_path: path to the video
    :param frames_dir: directory to save the frames
    :param overwrite: overwrite frames if they exist?
    :param every: extract every this many frames
    :return: path to the directory where the frames were saved, or None if fails
    """

    video_path = os.path.normpath(video_path)  # make the paths OS (Windows) compatible
    frames_dir = os.path.normpath(frames_dir)  # make the paths OS (Windows) compatible

    video_dir, video_filename = os.path.split(video_path)  # get the video path and filename from the path

    # make directory to save frames, its a sub dir in the frames_dir with the video name
    os.makedirs(os.path.join(frames_dir, video_filename), exist_ok=True)
    
    print("Extracting frames from {}".format(video_filename))
    
    extract_frames(video_path, frames_dir, every=every)  # let's now extract the frames

    return os.path.join(frames_dir, video_filename)  # when done return the directory containing the frames

# %%
# video_path = "../notebook/input.webm"
# output_folder = "unique_frames_output"

# video_to_frames(video_path=video_path, frames_dir=output_folder, overwrite=False, every=5)
# Out:
# Extracting frames from input.webm
# 'unique_frames_output\\input.webm'

# %% [markdown]
# ### generate emb

# %%
import os
image_folder_path = "../notebook/unique_frames_output/input.webm/"
image_file_path_list = [os.path.join(image_folder_path, x) for x in os.listdir(image_folder_path)]

# %%
import os
import torch
import numpy as np
from torchvision import models, transforms
from PIL import Image
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import hdbscan
import matplotlib.pyplot as plt
from collections import defaultdict

# 1. Load Pretrained MobileNetV2 Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.mobilenet_v2(pretrained=True).features
model.eval().to(device)

# MobileNetV2 Output: Last Conv layer gives (1280,) after GAP
gap = torch.nn.AdaptiveAvgPool2d(1)

# 2. Image Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# 3. Batched Feature Extraction
from tqdm import tqdm

def extract_features_batch(image_paths, batch_size=32):
    features = []
    batch = []
    paths_in_batch = []

    for idx, path in enumerate(tqdm(image_paths, desc="Loading Images")):
        try:
            img = Image.open(path).convert('RGB')
            img_tensor = transform(img)
            batch.append(img_tensor)
            paths_in_batch.append(path)
        except Exception as e:
            print(f"Error loading {path}: {e}")

        # When batch is ready or last image
        if len(batch) == batch_size or idx == len(image_paths) - 1:
            batch_tensor = torch.stack(batch).to(device)  # (B, 3, 224, 224)
            with torch.no_grad():
                feat_maps = model(batch_tensor)  # (B, 1280, 7, 7)
                pooled = gap(feat_maps).squeeze(-1).squeeze(-1)  # (B, 1280)
                features.append(pooled.cpu())

            # Reset batch
            batch = []
            paths_in_batch = []

    return torch.cat(features).numpy()  # (N, 1280)

# 4. Load All Image Features
image_folder = "../notebook/unique_frames_output/input.webm/"  # Replace with your folder
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('png', 'jpg', 'jpeg'))]
# Out:
# c:\Users\jignesh.shiyal\Documents\video_search_v3\env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\jignesh.shiyal\Documents\video_search_v3\env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
features = extract_features_batch(image_paths, batch_size=64)  # Tune batch_size for your GPU
# Out:
# Loading Images: 100%|██████████| 2640/2640 [01:22<00:00, 31.99it/s]

# %%
# 5. Dimensionality Reduction (Optional but helps clustering)
pca = PCA(n_components=264)
features_pca = pca.fit_transform(features)

# # 6a. Clustering using KMeans
# kmeans = KMeans(n_clusters=5, random_state=42)
# kmeans_labels = kmeans.fit_predict(features_pca)

# 6b. Clustering using HDBSCAN (auto-cluster count)
hdb = hdbscan.HDBSCAN(min_cluster_size=5)
hdb_labels = hdb.fit_predict(features_pca)

# 7. Visualization Function
def show_cluster_images(labels, img_paths, title="Clusters"):
    clusters = defaultdict(list)
    for label, path in zip(labels, img_paths):
        clusters[label].append(path)

    for label, paths in clusters.items():
        print(f"\nCluster {label} - {len(paths)} images")
        fig, axs = plt.subplots(1, min(len(paths), 5), figsize=(15, 5))
        for ax, img_path in zip(axs, paths[:5]):
            img = Image.open(img_path)
            ax.imshow(img)
            ax.axis('off')
        plt.suptitle(f"{title} - Cluster {label}", fontsize=16)
        plt.tight_layout()
        plt.show()

# 8. Show Results
# show_cluster_images(kmeans_labels, image_paths, "KMeans")
# show_cluster_images(hdb_labels, image_paths, "HDBSCAN")
# Out:
# c:\Users\jignesh.shiyal\Documents\video_search_v3\env\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\jignesh.shiyal\Documents\video_search_v3\env\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
clusering_result = {}
for cluster_label in hdb_labels:
    clusering_result[int(cluster_label)] = []

for cluster_label, path in zip(hdb_labels, image_paths):
    clusering_result[int(cluster_label)].append(path)

# %%
clusering_result
# Out:
# {15: ['../notebook/unique_frames_output/input.webm/0000000000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000065.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000075.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000080.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000085.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000090.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000095.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000100.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000105.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000185.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000190.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000195.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000200.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000205.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000210.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000220.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000225.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000230.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000280.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000285.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000290.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000295.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000300.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000305.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000310.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000315.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000320.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000325.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000330.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000335.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000340.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000345.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000350.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000355.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000360.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000365.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000370.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000375.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000380.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000385.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000390.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000395.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000400.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000405.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000410.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000415.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000420.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000425.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000430.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000435.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000440.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000445.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000450.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000455.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000460.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000465.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000470.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000475.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000480.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000485.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000490.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000495.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000500.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000505.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000510.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000515.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000520.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000525.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000530.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000535.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000540.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000545.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000655.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000660.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000665.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000670.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000675.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000680.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000685.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000690.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000695.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000700.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000705.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000710.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000715.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000720.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000725.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000730.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000735.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000740.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000745.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000750.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000755.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000760.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000765.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000770.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000775.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000780.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000785.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000790.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000795.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000800.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000930.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000935.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000940.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000945.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000950.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000955.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000960.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000965.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000970.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000975.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000980.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000985.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000000995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001065.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001790.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001795.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001800.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001805.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001810.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001815.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001820.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001825.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001830.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001835.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001840.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001845.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001850.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001855.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001860.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001865.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001870.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001875.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001880.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001885.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001940.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001945.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001950.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001955.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001960.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001965.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001970.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001975.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001980.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001985.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000001995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002065.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002075.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002080.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002085.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002090.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002095.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002100.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002105.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002185.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002190.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002195.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002200.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002205.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002210.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002475.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002480.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002485.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002490.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002495.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002500.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002505.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002510.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002515.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002520.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002525.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002530.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002535.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002540.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002545.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002550.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002555.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002560.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002565.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002570.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002575.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002580.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002585.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002590.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002595.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002600.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002605.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002610.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002615.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002620.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002625.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002630.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002655.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002660.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002665.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002670.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002675.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002680.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002685.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002690.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002695.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002700.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002705.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002710.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002715.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002720.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002725.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002730.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002735.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002740.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002745.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002750.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002755.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002760.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002765.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002770.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002775.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002780.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002785.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002790.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002795.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002800.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002805.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002810.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002815.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002820.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002825.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002830.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002835.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002840.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002845.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002850.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002855.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002860.jpg',
#   '../notebook/unique_frames_output/input.webm/0000002865.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003065.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003075.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003080.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003085.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003090.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003095.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003100.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003105.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003185.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003190.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003195.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003200.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003205.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003210.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003215.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003220.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003835.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003840.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003845.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003850.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003855.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003860.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003865.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003870.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003875.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003880.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003885.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003890.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003895.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003900.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003905.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003910.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003915.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003920.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003925.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003930.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003935.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003940.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003945.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003950.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003955.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003960.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003965.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003970.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003975.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003980.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003985.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000003995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004065.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004075.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004080.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004085.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004090.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004095.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004100.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004105.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004185.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004190.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004195.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004200.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004205.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004210.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004215.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004220.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004225.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004230.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004235.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004240.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004245.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004250.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004255.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004260.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004265.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004270.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004275.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004280.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004285.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004290.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004295.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004300.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004305.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004310.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004315.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004320.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004325.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004330.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004335.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004340.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004345.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004350.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004355.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004360.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004365.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004370.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004375.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004380.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004385.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004390.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004395.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004400.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004405.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004410.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004415.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004420.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004575.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004580.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004585.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004590.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004595.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004600.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004605.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004610.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004615.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004620.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004625.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004630.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004655.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004660.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004665.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004670.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004675.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004680.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004685.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004690.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004695.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004700.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004705.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004710.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004715.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004720.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004725.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004730.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004735.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004740.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004745.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004750.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004755.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004760.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004930.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004935.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004940.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004945.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004950.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004955.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004960.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004965.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004970.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004975.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004980.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004985.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000004995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005185.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005190.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005195.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005200.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005205.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005210.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005215.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005220.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005225.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005230.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005235.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005240.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005245.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005250.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005255.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005260.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005265.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005270.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005275.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005280.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005285.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005290.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005295.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005300.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005305.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005310.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005315.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005320.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005620.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005625.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005630.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005655.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005660.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005665.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005670.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005675.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005680.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005685.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005690.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005695.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005700.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005705.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005710.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005715.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005720.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005725.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005730.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005735.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005740.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005745.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005750.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005755.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005760.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005765.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005770.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005775.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005780.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005785.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005790.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005795.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005800.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005805.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005810.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005815.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005820.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005825.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005830.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005835.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005840.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005845.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005850.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005855.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005860.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005865.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005870.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005875.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005880.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005885.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005890.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005895.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005900.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005905.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005910.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005915.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005920.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005925.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005930.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005935.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005940.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005945.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005950.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005955.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005960.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005965.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005970.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005975.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005980.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005985.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000005995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006045.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006065.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006075.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006080.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006085.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006090.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006095.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006100.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006105.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006330.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006335.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006340.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006345.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006350.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006355.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006440.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006445.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006450.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006455.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006460.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006465.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006470.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006475.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006480.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006485.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006490.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006495.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006500.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006505.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006510.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006515.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006520.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006525.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006530.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006535.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006540.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006545.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006550.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006555.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006560.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006565.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006570.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006575.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006580.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006585.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006590.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006595.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006600.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006605.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006610.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006615.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006620.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006625.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006630.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006655.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006660.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006665.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006670.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006675.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006680.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006685.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006690.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006695.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006700.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006705.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006710.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006715.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006720.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006725.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006730.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006735.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006740.jpg',
#   '../notebook/unique_frames_output/input.webm/0000006745.jpg',
#   '../notebook/unique_frames_output/input.webm/0000007250.jpg',
#   '../notebook/unique_frames_output/input.webm/0000007255.jpg',
#   '../notebook/unique_frames_output/input.webm/0000007260.jpg',
#   '../notebook/unique_frames_output/input.webm/0000007265.jpg',
#   '../notebook/unique_frames_output/input.webm/0000007270.jpg',
#   '../notebook/unique_frames_output/input.webm/0000007275.jpg',
# ...
#   '../notebook/unique_frames_output/input.webm/0000009985.jpg',
#   '../notebook/unique_frames_output/input.webm/0000009990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000009995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010005.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010025.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010030.jpg'],
#  32: ['../notebook/unique_frames_output/input.webm/0000010060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010185.jpg'],
#  26: ['../notebook/unique_frames_output/input.webm/0000010110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010140.jpg'],
#  45: ['../notebook/unique_frames_output/input.webm/0000010310.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010315.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010320.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010325.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010330.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010335.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010340.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010345.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010350.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010355.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010360.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010365.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010370.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010375.jpg'],
#  49: ['../notebook/unique_frames_output/input.webm/0000010385.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010390.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010395.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010400.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010405.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010410.jpg'],
#  50: ['../notebook/unique_frames_output/input.webm/0000010415.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010420.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010425.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010430.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010435.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010440.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010445.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010450.jpg'],
#  48: ['../notebook/unique_frames_output/input.webm/0000010455.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010460.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010465.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010470.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010475.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010480.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010485.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010490.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010495.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010500.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010505.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010510.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010515.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010520.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010525.jpg'],
#  55: ['../notebook/unique_frames_output/input.webm/0000010555.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010560.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010565.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010570.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010575.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010580.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010585.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010590.jpg'],
#  56: ['../notebook/unique_frames_output/input.webm/0000010595.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010600.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010605.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010610.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010615.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010620.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010625.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010630.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000010655.jpg'],
#  22: ['../notebook/unique_frames_output/input.webm/0000011810.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011815.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011820.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011825.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011830.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011835.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011840.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011845.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011850.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011855.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011860.jpg',
#   '../notebook/unique_frames_output/input.webm/0000011865.jpg'],
#  42: ['../notebook/unique_frames_output/input.webm/0000012115.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012120.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012125.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012160.jpg'],
#  23: ['../notebook/unique_frames_output/input.webm/0000012295.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012300.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012305.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012310.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012315.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012320.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012325.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012330.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012335.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012340.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012345.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012350.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012355.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012360.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012365.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012370.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012375.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012380.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012385.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012390.jpg'],
#  25: ['../notebook/unique_frames_output/input.webm/0000012405.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012410.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012415.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012420.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012425.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012430.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012435.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012440.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012445.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012450.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012455.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012460.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012465.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012470.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012475.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012480.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012485.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012490.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012495.jpg'],
#  28: ['../notebook/unique_frames_output/input.webm/0000012500.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012505.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012510.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012515.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012520.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012525.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012530.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012535.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012540.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012545.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012550.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012555.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012560.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012565.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012570.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012575.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012580.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012585.jpg'],
#  29: ['../notebook/unique_frames_output/input.webm/0000012590.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012595.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012600.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012605.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012610.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012615.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012620.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012625.jpg'],
#  27: ['../notebook/unique_frames_output/input.webm/0000012630.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012635.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012640.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012645.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012650.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012655.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012660.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012665.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012670.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012675.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012680.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012685.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012690.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012695.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012700.jpg'],
#  30: ['../notebook/unique_frames_output/input.webm/0000012860.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012865.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012870.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012875.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012880.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012885.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012890.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012895.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012900.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012905.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012910.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012915.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012920.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012925.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012930.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012935.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012940.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012945.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012950.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012955.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012960.jpg'],
#  38: ['../notebook/unique_frames_output/input.webm/0000012990.jpg',
#   '../notebook/unique_frames_output/input.webm/0000012995.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013000.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013010.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013020.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013030.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013040.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013050.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013060.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013070.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013080.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013090.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013100.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013110.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013120.jpg'],
#  39: ['../notebook/unique_frames_output/input.webm/0000013015.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013035.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013055.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013075.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013095.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013115.jpg'],
#  31: ['../notebook/unique_frames_output/input.webm/0000013130.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013135.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013140.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013145.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013150.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013155.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013160.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013165.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013170.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013175.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013180.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013185.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013190.jpg',
#   '../notebook/unique_frames_output/input.webm/0000013195.jpg']}

# %% [markdown]
# ### Emb CLIP

# %%
import clip
import torch
from PIL import Image
from tqdm import tqdm

device = "cuda" if torch.cuda.is_available() else "cpu"

# Load the model (ViT-B/32 is fast, ViT-L/14 is more accurate)
model, preprocess = clip.load("ViT-B/32", device=device)
# Out:
# 100%|███████████████████████████████████████| 338M/338M [03:17<00:00, 1.79MiB/s]

# %%
def get_image_embedding(image_path):
    image = preprocess(Image.open(image_path).convert("RGB")).unsqueeze(0).to(device)
    with torch.no_grad():
        image_features = model.encode_image(image)
    return image_features.cpu().numpy()[0]  # Shape: (512,)

# %%
def get_image_embeddings_batch(image_paths, batch_size=32):
    all_embeddings = []
    for i in tqdm(range(0, len(image_paths), batch_size), desc="Extracting CLIP embeddings"):
        batch_paths = image_paths[i:i+batch_size]
        batch_images = [preprocess(Image.open(p).convert("RGB")) for p in batch_paths]
        batch_tensor = torch.stack(batch_images).to(device)
        with torch.no_grad():
            batch_features = model.encode_image(batch_tensor).cpu().numpy()
        all_embeddings.extend(batch_features)
    return all_embeddings  # Shape: (N, 512)

# %%
def get_text_embedding(text_query):
    text = clip.tokenize([text_query]).to(device)
    with torch.no_grad():
        text_features = model.encode_text(text)
    return text_features.cpu().numpy()[0]

# %%
from sklearn.metrics.pairwise import cosine_similarity

def find_similar_images(text_query, image_embeddings, image_paths, top_k=5):
    text_emb = get_text_embedding(text_query)
    sims = cosine_similarity([text_emb], image_embeddings)[0]
    top_indices = sims.argsort()[-top_k:][::-1]
    return [(image_paths[i], sims[i]) for i in top_indices]

# %%
tmp_cluster_result = []

for tmp_label in clusering_result.keys():
    tmp_image_list = clusering_result[tmp_label]
    tmp_cluster_result.append(tmp_image_list[-1])

# %%
len(tmp_cluster_result)
# Out:
# 58

# %%
image_paths = tmp_cluster_result  # Your clustered or full image list
image_embeddings = get_image_embeddings_batch(image_paths)
# Out:
# Extracting CLIP embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]

# %%
query = "transformer architecture"
results = find_similar_images(query, image_embeddings, image_paths)

for path, score in results:
    print(f"{path} (score: {score:.4f})")
# Out:
# ../notebook/unique_frames_output/input.webm/0000004925.jpg (score: 0.2749)
# ../notebook/unique_frames_output/input.webm/0000001510.jpg (score: 0.2589)
# ../notebook/unique_frames_output/input.webm/0000012160.jpg (score: 0.2586)
# ../notebook/unique_frames_output/input.webm/0000002470.jpg (score: 0.2471)
# ../notebook/unique_frames_output/input.webm/0000001640.jpg (score: 0.2455)
